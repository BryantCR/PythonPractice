# %%
import pandas as pd
from pathlib import Path

mypath = Path(r"C:\Users\bryan\Downloads\WIexported\Testingexport.csv")

# %%
#df = pd.read_csv(mypath / "WIexported.csv")
df = pd.read_csv(mypath, parse_dates=['State'])
df.head()
# Out:
# C:\Users\bryan\AppData\Local\Temp\ipykernel_9816\598864173.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(mypath, parse_dates=['State'])
#     ID Work Item Type           Title                            Assigned To  \
# 0  529     User Story             526  Johan Sanchez <johansg14@hotmail.com>
# 1  530     User Story           holis                                    NaN
# 2  531     User Story        gdzfgdff                                    NaN
# 3  532     User Story  testeo intenso                                    NaN
# 4  533     User Story              mm                                    NaN
#
#     State  Tags
# 0  Closed   NaN
# 1     New   NaN
# 2     New   NaN
# 3     New   NaN
# 4     New   NaN

# %%
df.tail()
# Out:
#     ID Work Item Type  Title Assigned To State  Tags
# 5  534     User Story      l         NaN   New   NaN
# 6  535     User Story   jkbh         NaN   New   NaN
# 7  536     User Story    o8h         NaN   New   NaN
# 8  537     User Story      h         NaN   New   NaN
# 9  538     User Story  knuhy         NaN   New   NaN

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 3.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.0 MB 9.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 12.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 12.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.8 MB 15.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.8 MB 16.9 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.8 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 16.5 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
# ...
